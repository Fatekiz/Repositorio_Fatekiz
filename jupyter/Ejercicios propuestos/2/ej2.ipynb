# %% [markdown]
# # Importando libreria

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Se tiene un dataset de películas obtenidas de IMDB (Internet Movie Database), el cual contiene información como título, año de estreno, director, ratings, puntuaciones y otras columnas. Se solicita:

# %%
databasePelis = pd.read_csv('assets/data/datanueva.csv', index_col='ID')
databasePelis.head()
# Out:
#                 Series_Title  \
# ID
# 1   The Shawshank Redemption
# 2              The Godfather
# 3            The Dark Knight
# 4     The Godfather: Part II
# 5               12 Angry Men
#
#                                           Poster_Link Released_Year  \
# ID
# 1   https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 2   https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 3   https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 4   https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# 5   https://m.media-amazon.com/images/M/MV5BMWU4N2...          1957
#
#    Certificate  Runtime                 Genre  IMDB_Rating  \
# ID
# 1            A  142 min                 Drama          9.3
# 2            A  175 min          Crime, Drama          9.2
# 3           UA  152 min  Action, Crime, Drama          9.0
# 4            A  202 min          Crime, Drama          9.0
# 5            U   96 min          Crime, Drama          9.0
# ...

# %% [markdown]
# #### A. Mostrar la cantidad de filas nulas de las columnas ‘Certificate’ y ‘Meta_score’

# %%
columnas = ['Certificate', 'Meta_score']
valores_nulos = databasePelis[columnas].isnull().sum()
print(f"Cantidad de filas nulas en las columnas: \n {valores_nulos}")
# Out:
# Cantidad de filas nulas en las columnas:
#  Certificate    101
# Meta_score     157
# dtype: int64

# %% [markdown]
# #### B. Eliminar las filas nulas de las columnas anteriormente nombradas

# %%
data_sin_nulos = databasePelis[columnas].dropna()
data_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 787 entries, 1 to 998
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Certificate  787 non-null    object
#  1   Meta_score   787 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 18.4+ KB

# %% [markdown]
# #### C. Obtener el promedio de los 10 primeros Directores desde la columna ‘Meta_score’ (Puntuación de la Película).

# %%
pro_direc = ['Meta_score']
promedio = databasePelis[pro_direc].head(10).mean()
promedio
# Out:
# Meta_score    87.2
# dtype: float64

# %% [markdown]
# #### D. Aplicar un filtro utilizando una función que muestre solamente las películas del género de Guerra (War) generando un nuevo dataframe con las columnas: ID, Series_Title, IMDB_Rating y Meta_score. Exportar y guardar este nuevo dataset con la función correspondiente de pandas.

# %%
def filtro(genres):
    return 'War' in genres

columnas_mostrar = ['ID', 'Series_Title', 'IMDB_Rating', 'Meta_score']
Gen_war = databasePelis[databasePelis['Genre'].apply(filtro)]

# %%
Gen_war[['Series_Title', 'IMDB_Rating', 'Meta_score']].head(15)
# Out:
#                  Series_Title  IMDB_Rating  Meta_score
# ID
# 25        Saving Private Ryan          8.6        91.0
# 47             Hotaru no haka          8.5        94.0
# 51                 Casablanca          8.5       100.0
# 75             Apocalypse Now          8.4        94.0
# 81             Paths of Glory          8.4        90.0
# 84         The Great Dictator          8.4         NaN
# 85                       1917          8.3        78.0
# 91                  Incendies          8.3        80.0
# 94       Inglourious Basterds          8.3        69.0
# 105         Full Metal Jacket          8.3        76.0
# 106              Idi i smotri          8.3         NaN
# 130  Uri: The Surgical Strike          8.2         NaN
# 139               Mandariinid          8.2        73.0
# 151           Pan's Labyrinth          8.2        98.0
# 173                       Ran          8.2        96.0

# %% [markdown]
# #### E. Crear en un gráfico de barra, donde compare la puntuación del IMDB_Rating y Meta_score de las primeras 10 películas del género de guerra.
