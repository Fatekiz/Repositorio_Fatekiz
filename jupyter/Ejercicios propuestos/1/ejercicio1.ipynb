# %% [markdown]
# # Ejercicio 1
# #### Generar dos vectores aleatorios de valores enteros (del 1 al 10). Los vectores solamente deben tener 5 elementos y se deben sumar sus elementos para obtener un único vector

# %%
# llamando bibliotecas
import numpy as np

# %%
vector1 = np.random.randint(1,11,5)
vector1
# Out:
# array([ 9,  7,  5, 10,  7])

# %%
vector2 = np.random.randint(1,11,5)
vector2
# Out:
# array([1, 8, 1, 8, 5])

# %%
# sumando los vectores
suma_vectores = vector1 + vector2
suma_vectores
# Out:
# array([10, 15,  6, 18, 12])

# %% [markdown]
# # Utilizar la biblioteca de matplotlib para graficar el vector previamente generado

# %%
#importando lib matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(suma_vectores, label = "vector")
plt.title("Grafico de la suma de vectores")
plt.grid(True)
plt.legend()

# %% [markdown]
# # 3.- obtener el promedio de una matriz generada de forma aleatoria, esta matriz tiene que tener una dimension de 10x10 (numeros enteros del 1 al 10)

# %%
matriz = np.random.randint(1,11,100)
matriz
# Out:
# array([ 8,  1,  4, 10,  6, 10,  5,  6,  5,  9,  4,  1,  5,  7,  4, 10,  9,
#         2, 10,  1,  4, 10,  6, 10,  3,  5,  5,  7,  9, 10,  9,  3,  5, 10,
#         1,  7,  8,  8,  7,  7,  6,  5, 10, 10,  9,  5,  3,  3,  3,  3,  2,
#         1,  1,  3,  5,  4, 10,  6,  2,  4,  6,  9,  7,  8,  7,  3,  5,  4,
#         5,  3,  4,  4,  8,  2,  5, 10, 10,  2,  1,  2,  2,  7,  1,  6,  1,
#         2,  4,  3,  4,  5,  5,  3,  7,  3,  9,  9,  4,  2,  8,  4])

# %%
matriz.reshape(10,10)
# Out:
# array([[ 8,  1,  4, 10,  6, 10,  5,  6,  5,  9],
#        [ 4,  1,  5,  7,  4, 10,  9,  2, 10,  1],
#        [ 4, 10,  6, 10,  3,  5,  5,  7,  9, 10],
#        [ 9,  3,  5, 10,  1,  7,  8,  8,  7,  7],
#        [ 6,  5, 10, 10,  9,  5,  3,  3,  3,  3],
#        [ 2,  1,  1,  3,  5,  4, 10,  6,  2,  4],
#        [ 6,  9,  7,  8,  7,  3,  5,  4,  5,  3],
#        [ 4,  4,  8,  2,  5, 10, 10,  2,  1,  2],
#        [ 2,  7,  1,  6,  1,  2,  4,  3,  4,  5],
#        [ 5,  3,  7,  3,  9,  9,  4,  2,  8,  4]])

# %%
# obtener promedio
np.mean(matriz)
# Out:
# 5.4
